# %%
import pandas as pd
import numpy as np

import io
from google. colab import files
uploaded =files.upload()
import io
df2 = pd.read_csv(io.BytesIO(uploaded['DAhouseprices.csv']))
# Dataset is now stored in a Pandas Dataframe
# Out:
#      <input type="file" id="files-c7f18393-c293-4905-9f48-e1d17ead9222" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7f18393-c293-4905-9f48-e1d17ead9222">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
path= "DAhouseprices.csv"

# %%
df= pd.read_csv(path)

# %%
df.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   landcontour utilities  ... poolarea poolqc fence miscfeature miscval mosold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   yrsold  saletype  salecondition  saleprice
# ...

# %%
pd.set_option('display.max_columns',81)
df.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   landcontour utilities lotconfig landslope neighborhood condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   condition2 bldgtype housestyle  overallqual  overallcond  yearbuilt  \
# ...

# %%
df_schema=pd.read_csv('DAhouseprices.csv')
df_schema
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
orders = pd.read_csv('DAhouseprices.csv')
orders.isnull().sum()
# Out:
# id                 0
# mssubclass         0
# mszoning           0
# lotfrontage      259
# lotarea            0
#                 ...
# mosold             0
# yrsold             0
# saletype           0
# salecondition      0
# saleprice          0
# Length: 81, dtype: int64

# %%
orders.notnull().head()
# Out:
#      id  mssubclass  mszoning  lotfrontage  lotarea  street  alley  lotshape  \
# 0  True        True      True         True     True    True  False      True
# 1  True        True      True         True     True    True  False      True
# 2  True        True      True         True     True    True  False      True
# 3  True        True      True         True     True    True  False      True
# 4  True        True      True         True     True    True  False      True
#
#    landcontour  utilities  lotconfig  landslope  neighborhood  condition1  \
# 0         True       True       True       True          True        True
# 1         True       True       True       True          True        True
# 2         True       True       True       True          True        True
# 3         True       True       True       True          True        True
# 4         True       True       True       True          True        True
#
# ...

# %%
orders.shape
# Out:
# (1460, 81)

# %%
orders[orders['lotfrontage'].isnull()]
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
# 1431  1432         120       RL          NaN     4928   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
#
# ...

# %%
#Get unique entries of a column with DAhouseprices()
df ['mszoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
df['street'].unique()
# Out:
# array(['Pave', 'Grvl'], dtype=object)

# %%
df.describe()
# Out:
#                 id   mssubclass  lotfrontage        lotarea  overallqual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        overallcond    yearbuilt  yearremodadd   masvnrarea   bsmtfinsf1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df[['saleprice']].describe()
# Out:
#            saleprice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
df[['lotarea']].describe()
# Out:
#              lotarea
# count    1460.000000
# mean    10516.828082
# std      9981.264932
# min      1300.000000
# 25%      7553.500000
# 50%      9478.500000
# 75%     11601.500000
# max    215245.000000

# %%
df[['openporchsf']].describe()
# Out:
#        openporchsf
# count  1460.000000
# mean     46.660274
# std      66.256028
# min       0.000000
# 25%       0.000000
# 50%      25.000000
# 75%      68.000000
# max     547.000000

# %%
df[['openporchsf','saleprice']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   openporchsf  1460 non-null   int64
#  1   saleprice    1460 non-null   int64
# dtypes: int64(2)
# memory usage: 22.9 KB

# %%
with_open_porches = df[['openporchsf','saleprice']].iloc[(df['openporchsf']>0).values] 
with_open_porches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   openporchsf  804 non-null    int64
#  1   saleprice    804 non-null    int64
# dtypes: int64(2)
# memory usage: 18.8 KB

# %%
without_open_porches = df[['openporchsf','saleprice']].iloc[(df['openporchsf'] == 0).values]
without_open_porches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 656 entries, 1 to 1458
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   openporchsf  656 non-null    int64
#  1   saleprice    656 non-null    int64
# dtypes: int64(2)
# memory usage: 15.4 KB

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(with_open_porches['saleprice'], without_open_porches['saleprice'])
# Out:
# Ttest_indResult(statistic=17.31355834212178, pvalue=3.209770265256579e-61)

# %%
from scipy import stats
stats.pearsonr(df['saleprice'],df['lotarea'])
# Out:
# (0.2638433538714057, 1.1231391549193063e-24)
